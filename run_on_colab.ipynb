# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/PA2_code
# !ls
# Out:
# Mounted at /content/drive

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# !python main.py
# Out:
# Loading data and creating tokenizer ...
# Vocabulary size is 5755
# Token for the word 'the' is 5209
# Number of samples in the training dataset is 2092
# First sample shape: torch.Size([21])
# First sample dtype: torch.int64
# First label: 0
# Number of samples in the training dataset is 32039
# x shape: torch.Size([32])
# y shape: torch.Size([32])
# x dtype: torch.int64
# y dtype: torch.int64
# x first 10 tokens: tensor([5558, 2361, 3208,  358, 1344, 3794, 5009, 4922, 1970, 1478])
# y first 10 tokens: tensor([2361, 3208,  358, 1344, 3794, 5009, 4922, 1970, 1478, 3573])

# %%
# Out:
# dataset.py  run_on_colab.ipynb	tokenizer.py	utilities.py
# main.py     speechesdataset	transformer.py
